# %% [markdown]
# ## Screen!

# %%
from PIL import Image as PILImage
from IPython.display import Image

name = 'obj/african_head_diffuse.tga'

pil_im = PILImage.open(name, 'r')
pil_im.save('temp.jpg')
Image(filename='temp.jpg')
